# %%
a ={}
type (a)
# Out:
# dict

# %%
a = {1:100,2:200,3:300}
a
# Out:
# {1: 100, 2: 200, 3: 300}

# %%
c = {'name':'python','age':25,2:22.2}
c
# Out:
# {'name': 'python', 'age': 25, 2: 22.2}

# %%
g = {1:100,1:200,1:'java'}      #duplicates key not allow
g
# Out:
# {1: 'java'}

# %%
# Iterable: collection of elements, we have more than oe element
s = {(1,2),'sourabh'}
s
# Out:
# {(1, 2), 'sourabh'}

# %%
t = {1:100,2:100,3:100}    # duplicate values are allowed
t

# %%
# Dict is Mutable

# %%
x ={}
x
# Out:
# {}

# %%
x.update({1:200,2:100})
x
# Out:
# {1: 200, 2: 100}

# %%
x.update({2:'jay'})
x
# Out:
# {1: 200, 2: 'jay'}

# %%
x.setdefault(4)  # for key 4 it will add None as a value 4: None
x
# Out:
# {1: 200, 2: 'jay', 4: None}

# %%
x.keys()
# Out:
# dict_keys([1, 2, 4])

# %%
x.values()
# Out:
# dict_values([200, 'jay', None])

# %%
x.items()
# Out:
# dict_items([(1, 200), (2, 'jay'), (4, None)])
