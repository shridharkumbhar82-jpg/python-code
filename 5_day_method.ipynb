# %%
p = [10,20,30]
p
# Out:
# [10, 20, 30]

# %%
p[-1] ='shri'

# %%
p
# Out:
# [10, 20, 'shri']

# %%
p.remove(10)
p
# Out:
# [20, 'shri']

# %%
p.insert(0,'laximi')
p
# Out:
# ['laximi', 20, 'shri']

# %%
t = [10,20,30]
t
# Out:
# [10, 20, 30]

# %%
t[-1] = 'anand'
t
# Out:
# [10, 20, 'anand']

# %%
t.remove(20)
t
# Out:
# [10, 'anand']

# %%
t[-1] ="shridhar"
t
# Out:
# [10, 'shridhar']

# %%
a= 23
b=45
c=56

num =

# %%
x = [1,2,3,4]# this is homogenioues list
x
# Out:
# [1, 2, 3, 4]

# %%
y = [1,'pyhton',3.34,(4+3j)]   # this is hetro list
y
# Out:
# [1, 'pyhton', 3.34, (4+3j)]

# %%
 # list support indexing and sclicing bcz internal data structure is array

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
x[2]
# Out:
# 3

# %%
x[-1]
# Out:
# 4

# %%
x[1:3]
# Out:
# [2, 3]

# %%
k = [1,34,65,76,1,1,11,2] # duplicate are allow in list
k
# Out:
# [1, 34, 65, 76, 1, 1, 11, 2]

# %%
d=["a"]

# %%
d.append('A')

# %%
d
# Out:
# ['a', 'A']

# %%
d.append([2,3])

# %%
d
# Out:
# ['a', 'A', [2, 3]]

# %% [markdown]
# # you can this difference in append and extend method below and above
# # append add complete object where extend add individual element form objecr

# %%
p=[]
p.extend([10,20,30])

# %%
p
# Out:
# [10, 20, 30]

# %%
p.append([10,20,30])

# %%
p
# Out:
# [10, 20, 30, [10, 20, 30]]

# %%
p.append('java')

# %%
p
# Out:
# [10, 20, 30, [10, 20, 30], 'java']

# %%
p.extend('java')

# %%
p
# Out:
# [10, 20, 30, [10, 20, 30], 'java', 'j', 'a', 'v', 'a']

# %% [markdown]
# # remove all element in list
# p.clear()

# %%
p.clear()

# %%
p
# Out:
# []

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
# pop method is uesd to (always) delete last element

# %%
x.pop()
# Out:
# 4

# %%
x
# Out:
# [1, 2, 3]
