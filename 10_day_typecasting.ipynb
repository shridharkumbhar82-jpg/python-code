# %%
 # mutable - list,set,dic
# immutable - tuple,string,numeic:int,float,complex

# %% [markdown]
# ### typecasting

# %%
num = '100'
num
# Out:
# '100'

# %%
num + 50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 num + 50
#
# TypeError: can only concatenate str (not "int") to str

# %%
# use typecating 
int(num)+50
# Out:
# 150

# %%
float(5.2+50)
# Out:
# 55.2

# %%
list('mayuresh')  # str is collection of block hence you can get
# Out:
# ['m', 'a', 'y', 'u', 'r', 'e', 's', 'h']

# %%
list(('mayuresh',))      # in this we have single element not a block of chars , hence object is converted
# Out:
# ['mayuresh']

# %%
roll_no = [101,102,103,101,102,104]
roll_no
# Out:
# [101, 102, 103, 101, 102, 104]

# %%
set(roll_no)   # to avoid duplicates
# Out:
# {101, 102, 103, 104}

# %%
# convert two tuple in dict

t = (1,2,3)
t1 = ('a','b','c')
zip(t,t1)  #(key,value)

# %%
list(zip(t,t1))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
dict(zip(t,t1))
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
t1
# Out:
# ('a', 'b', 'c')

# %%
list(enumarate(t1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 list(enumarate(t1))
#
# NameError: name 'enumarate' is not defined

# %%
# find unique word is sentence
m1 ='python is simple simle'
m2 =' i love python and its simple'

# %%
set(m1.split()).intersection(set(m2.split()))     # divide sentence in word
# Out:
# {'python', 'simple'}

# %%
set(m1.split()).union(set(m2.split()))
# Out:
# {'and', 'i', 'is', 'its', 'love', 'python', 'simle', 'simple'}
