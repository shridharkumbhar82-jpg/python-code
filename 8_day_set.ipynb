# %%
#set and dictionary both are mutable(you can change)
s={}
type(s)
# Out:
# dict

# %%
# altist one element in set
s1={1}
type(s1)
# Out:
# set

# %%
# in set duplicates are not allow
a= {1,1,2,2,4,5,6,3,3,3,65,67,8987}
a
# Out:
# {1, 2, 3, 4, 5, 6, 65, 67, 8987}

# %%
# doesnt preserv sequece orsder
b ={1,2,3,'shri',3,4,6,7,7,7,8,8,8,'a'}
b
# Out:
# {1, 2, 3, 4, 6, 7, 8, 'a', 'shri'}

# %%
b.pop() #  its delete random element
# Out:
# 'shri'

# %%
lot = {111,3,333,44,}

# %%
winner =lot.pop()

# %%
winner
# Out:
# 3

# %%
print('original lot:',lot)
out =lot.pop()
print('element removed:',out,'curruent set',lot)
# Out:
# original lot: {44, 333, 111}
# element removed: 44 curruent set {333, 111}

# %%
a  #duplicates are not allow in set
# Out:
# {1, 2, 3, 4, 5, 6, 65, 67, 8987}

# %%
b
# Out:
# {1, 2, 3, 4, 6, 7, 8, 'a', 'shri'}
