# %%
def test(num):
    return num*num
    #print(num*num)

result = test(10)

# %%
result+50
# Out:
# 150

# %%
def exam(per):
    if per>=60:
        return'pass'
    else:
        return'fail'

result=exam(64)    

def final(result):
    if result=='pass':
        print('welcome to interview')

    else:
        print('try next year')
        
    
final(result)
# Out:
# welcome to interview

# %% [markdown]
# ### lambda fuction

# %%
sq = lambda num:num*num
sq(5)
# Out:
# 25

# %%
# we can give multiple parameters but only one expresion is allow

# %%
def sq(num):
    return num*num
sq(4)
# Out:
# 16

# %%
# ternary opration express_1 if <condition> else express_2

# %%
a = 22
out = 'you can vote' if a>18 else 'you are not eligible'
print('Final ans is:',out)
# Out:
# Final ans is: you can vote

# %%
cheak = lambda val:'happy' if val>70 else'unhappy'
cheak(58)
# Out:
# 'unhappy'
