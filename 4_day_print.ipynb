# %%
# .2f is used to print only 2 digits like 34.45

txt = "for only {price:.2f}dollar!"
print(txt.format(price=34.45435))
# Out:
# for only 34.45dollar!

# %%
name ="shri"
age = 25
print('my name is:', name ,'and my age is:',age)
# Out:
# my name is: shri and my age is: 25

# %%
name = "anand"
age = 22
print(f"my name is :{name} and my age is:{age}")
# Out:
# my name is :anand and my age is:22

# %%
print(100,200,'pyhton',sep='\t')
print(100,200,'pyhton',sep='\n')
# Out:
# 100	200	pyhton
# 100
# 200
# pyhton

# %%
print("hello guys",end =" ")   # space give you single line in end
print("good night")
# Out:
# hello guys good night

# %%
print("hello students",end=' ')
print("welcome")
# Out:
# hello students welcome
