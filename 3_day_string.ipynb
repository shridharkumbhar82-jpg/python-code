# %%
a = "python java"

# %%
a.upper()
# Out:
# 'PYTHON JAVA'

# %%
a.replace('java','net')
# Out:
# 'python net'

# %%
b ='1111-2222-3333'
b
# Out:
# '1111-2222-3333'

# %%
b.split('-')
# Out:
# ['1111', '2222', '3333']

# %%
b.split('-')[-3]
# Out:
# '1111'

# %%
c = ["hello","good eveninig","python"]

# %%
"--".join(c)
# Out:
# 'hello--good eveninig--python'

# %%
d1 = [1,12,3,4]

# %%
d2 = ['shri',34.44,1,4+3j,[1,2,4]]
d2
# Out:
# ['shri', 34.44, 1, (4+3j), [1, 2, 4]]

# %% [raw]
# help(str.c)

# %% [markdown]
# # Assignment

# %% [markdown]
# ### Reamning method of string

# %%
c = (" this is data science and genAI coures")

# %%
str.capitalize(c)             # used for every letttet"s become small formate
# Out:
# ' this is data science and genai coures'

# %%
# (2) basically use match two thing are similar or not    " casefold method "


text1 = "hello guys"
text2 = "this python course"
if text1.casefold() == text2.casefold():
    print("the string is eqaal for searching.")
else:
    print("not maching")


# str.casefold(c)
# Out:
# not maching

# %%
c
# Out:
# ' this is data science and genAI coures'

# %%
# (3) the sentence goes to right side

print(c.center(50))
# Out:
#        this is data science and genAI coures

# %%
c
# Out:
# ' this is data science and genAI coures'

# %%
#(4) this is not working i have chack    Q

c.count('c')
# Out:
# 3

# %%
#(5) i think it give seprate line and name of that line

c.encode()
# Out:
# b' this is data science and genAI coures'

# %%
c
# Out:
# ' this is data science and genAI coures'

# %%
# (6)print last word or letter using (" endswith ")  Q

b = c.endswith('course')
print(b)
# Out:
# False

# %%
#(7)
d = c.startswith('this')
print(d)
# Out:
# False

# %%
#(8) right now its not imp 

text_with_tabs = "name\t age\t city"

default_expand = text_with_tabs.expandtabs()
print("default (tabsize=8:\n'{default_expanded}'")
# Out:
# default (tabsize=8:
# '{default_expanded}'

# %%
#(9) show digit of letter you want to find

c.find("data")
# Out:
# 9

# %%
#(10)  join the name's over sentence

print("the quick {} {} juped over the lazy {}.".format("brown","fox","dog"))
# Out:
# the quick brown fox juped over the lazy dog.

# %%
# (11) format_map similar to previous
data = {
    "name" : "shridhar",
    "item" : "laptop",
    "price" : 500000
}

template_string = "Hello, {name} ! your {item} cost {price:}."

massage = template_string.format_map(data)

print(massage)
# Out:
# Hello, shridhar ! your laptop cost 500000.

# %%
c
# Out:
# ' this is data science and genAI coures'

# %%
#(12) index metod
c[2]
# Out:
# 'h'

# %%
# (13)
#str1 ="hello123"       # True if all characters in the string are letters or numbers and the string has at least one character.
#print(str1.isalnum())

str2 ="hello 123"       #False if the string contains any non-alphanumeric symbols (like spaces, punctuation marks, or special characters), or if the string is empty
print(str2.isalnum())
# Out:
# False

# %%
# (14)

str1 = "python"          # Returns True because all characters are letters
print(str1.isalpha())

#str2 =" pythön"          # Returns True because it contains only alphabetic characters, including non-ASCII
#print(str2.isalpha())

                     # below some rules
# Returns False because it contains a number.... like =
# Returns False because it contains a space...like =
# Returns False because the string is empty....like = 
# Returns False because it contains a special character...like = "Python!"
# Returns False because it contains punctuation  ....like = "Isalpha?"
# Out:
# True

# %%
# (15) isascii() method
