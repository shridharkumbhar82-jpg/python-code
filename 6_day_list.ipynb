# %% [markdown]
# #

# %%
A = [20,30,40]
A
# Out:
# [20, 30, 40]

# %%
A[-1]
# Out:
# 40

# %%
A[-1] =300 # list mutable so you can change using replace
A
# Out:
# [20, 30, 300]

# %%
# string are immutable because we cant change in string

# %%
B =A.copy()       # uesd to capy same method as it is
B
# Out:
# [20, 30, 300]

# %%
A.append(500)

# %%
A
# Out:
# [20, 30, 300, 500]

# %%
# shall copy create a new object  but its have his own identity 
# to cheak memory id ()  is used

# %%
# deep copy 
c=A

# %%
c
# Out:
# [20, 30, 300, 500]

# %%
id(A),id(c)
# Out:
# (2737743731392, 2737743731392)

# %%
A.append(900)
A
# Out:
# [20, 30, 300, 500, 900, 900]

# %%
c                      # now it does same opration in both A and c
# Out:
# [20, 30, 300, 500, 900, 900]

# %%
k = [45,3,5,65,8,94,26,7]      # sort is used for assending order
k.sort()
k
# Out:
# [3, 5, 7, 8, 26, 45, 65, 94]

# %%
k
# Out:
# [3, 5, 7, 8, 26, 45, 65, 94]

# %%
# random list and 2nd largest number print
j =[10,20,340,56]
j.sort()
j[-2]
# Out:
# 56
