# %%
# position argument positon and sequence matter in case
def info(name,age,salary):
    print('name:',name,'age:',age,'salary:',salary)

info("shri",25,80000)
# Out:
# name: shri age: 25 salary: 80000

# %%
# if change the squence of calling
info(25,80000,"shri")
# Out:
# name: 25 age: 80000 salary: shri

# %%
# keyword args  : in which squence order doesn't matter
info (age=25,salary=90000,name="shri")
# Out:
# name: shri age: 25 salary: 90000

# %%
def test(name='guest',place='pune'):
    print(name,place)
info()
# Out:
# guest pune

# %%
test('pranav')
# Out:
# pranav pune

# %%
# variable lenth args
# var len potion args/* args
# car len keyword args/**kwrgs

# %%
def test(*a):
    print(a)

test(10,20,30)
test(80)
# Out:
# (10, 20, 30)
# (80,)

# %%
def test(**a):
    print(a)
test()
# Out:
# {}

# %%
test(a=10,b=20)
# Out:
# {'a': 10, 'b': 20}

# %%
test(name='python',age=34)
# Out:
# {'name': 'python', 'age': 34}
