# %%
# to cheak all the fuction present in pyhton
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# we can not use above keywoed as a fuction or variable
class = 34
# Out:
#   Cell In[3], line 2
#     class = 34
#           ^
# SyntaxError: invalid syntax

# %%
# def fuction_name ():

def sample(): # Declaration
    # indentation we say this space
    print("Welcome to sample fuction")

    # to get answer we have call it fuction
sample()
# Out:
# Welcome to sample fuction

# %%
def addition():
    a = 200
    b = 300
    print("the sum of:",a+b)
addition()
# Out:
# the sum of: 500

# %%
def addition():
    num1 = int(input("Enter a number:"))
    num2 = int(input("Enter 2nd number:"))
    print("the sum is:",num1+num2)
addition()
# Out:
# Enter a number: 2
# Enter 2nd number: 5
# the sum is: 7

# %%
# taking a input outside the fuction

def addition(num1,num2):
    print("the sum is:",num1+num2)

num1 = int(input("Enter a number"))
num2 = int(input("Enter a number"))

addition(num1,num2)
# Out:
# Enter a number 2
# Enter a number 3
# the sum is: 5

# %%
k = [100,2,6,1,60]
k
# Out:
# [100, 2, 6, 1, 60]

# %%
len(k)
# Out:
# 5

# %%
sum(k)  # this are built in fuctions
# Out:
# 169

# %%
min(k)
# Out:
# 1

# %%
max(k)
# Out:
# 100

# %%
# sorted(itrable)
sorted(k)
# Out:
# [1, 2, 6, 60, 100]

# %%
reversed(k)

# %%
tuple(reversed(k))
# Out:
# (60, 1, 6, 2, 100)
