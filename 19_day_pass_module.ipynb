# %%
def test():
    #print(1)
    return 10

# %%
result=test()
def process(result):
    print("final answer is:",result+100)

process(result)
# Out:
# final answer is: 110

# %% [markdown]
# ### pass

# %%
# is used to create empty block

# %% [markdown]
# ### modules

# %%
# a file with.py extension is a python file and it is called module
#1.built in module
#2.user defined modulde

# %%
import math

# %%
math.pi # we are using.dot operator to access member of module
# Out:
# 3.141592653589793

# %%
math.factorial(4)
# Out:
# 24
