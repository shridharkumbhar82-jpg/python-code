# %%
n = 'shridhar'
# [(index,char)]
[val for val in enumerate(n)]
# Out:
# [(0, 's'),
#  (1, 'h'),
#  (2, 'r'),
#  (3, 'i'),
#  (4, 'd'),
#  (5, 'h'),
#  (6, 'a'),
#  (7, 'r')]

# %%
#dict comprehension (key,values)
n = 'shrid h  ar'
{index:val for index,val in enumerate(n) if val!=''}
# Out:
# {0: 's',
#  1: 'h',
#  2: 'r',
#  3: 'i',
#  4: 'd',
#  5: ' ',
#  6: 'h',
#  7: ' ',
#  8: ' ',
#  9: 'a',
#  10: 'r'}

# %%
t1 =[10,20,30]
t2 =['A','B','C']
for i in range(len(t1)):
    print(i)
{t2[i]:t1[i]for i  in range(len(t1))}
# Out:
# 0
# 1
# 2
# {'A': 10, 'B': 20, 'C': 30}
