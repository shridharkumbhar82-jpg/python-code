# %%
t = ()   # empty tuple
t
# Out:
# ()

# %%
a = (1,23,4+j,'shri')  # hetrogenus
b =(1,2,3)                # homogenus

# %%
# tuple support indexing and slicing 
# duplicates also allow

# %%
p=[10,20,30]
p
# Out:
# [10, 20, 30]

# %%
p[-1]='shri'

# %%
p
# Out:
# [10, 20, 'shri']

# %%
# using insert(index,value) to add element using index
# this mutable example
p.insert(0,'omkar')
p
# Out:
# ['omkar', 'omkar', 'omkar', 10, 20, 'shri']

# %%
p.remove('omkar')   # when you use remove method you have gave name(digit)
p
# Out:
# ['omkar', 10, 20, 'shri']

# %%
k = (10,20,30)   # tuple is immutable it can not be change
k
# Out:
# (10, 20, 30)

# %%
k.remove(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 k.remove(10)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
k[-1]= 'shridhar'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 k[-1]= 'shridhar'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# tuple packing and unpaking  , you can aslo add name
a = 10 
b = 20
c = 30

# %%
a,b,c
# Out:
# (10, 20, 30)

# %%
nums = a,b,c

# %%
nums
# Out:
# (10, 20, 30)

# %%
# unpacking
num1,name,num2 =nums

# %%
num1
# Out:
# 10

# %%
name
# Out:
# 20
